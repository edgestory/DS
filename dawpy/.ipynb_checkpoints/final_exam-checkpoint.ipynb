# %%
import pandas as pd
data = pd.read_csv('gender.csv',encoding='cp949')

# %%
data.head()
# Out:
#                           행정구역  2019년02월_남_총인구수  2019년02월_남_연령구간인구수  \
# 0          서울특별시  (1100000000)          4773605             4773605
# 1       서울특별시 종로구 (1111000000)            74662               74662
# 2  서울특별시 종로구 청운효자동(1111051500)             6088                6088
# 3    서울특별시 종로구 사직동(1111053000)             4313                4313
# 4    서울특별시 종로구 삼청동(1111054000)             1328                1328
#
#    2019년02월_남_0세  2019년02월_남_1세  2019년02월_남_2세  2019년02월_남_3세  2019년02월_남_4세  \
# 0          27977          30473          33735          36145          35828
# 1            318            334            395            434            435
# 2             27             39             36             55             53
# 3             19             30             27             34             33
# 4              6              6              2              9              7
#
#    2019년02월_남_5세  2019년02월_남_6세  ...  2019년02월_여_91세  2019년02월_여_92세  \
# 0          35485          38974  ...            5394            4054
# 1            426            501  ...             114              86
# 2             44             50  ...               4               4
# 3             37             41  ...              10               3
# 4              4              2  ...               5               2
#
#    2019년02월_여_93세  2019년02월_여_94세  2019년02월_여_95세  2019년02월_여_96세  \
# 0            3072            2187            2069            1664
# 1              71              55              41              49
# 2               9               3               3               4
# 3               8               2               5               6
# 4               0               2               0               1
#
#    2019년02월_여_97세  2019년02월_여_98세  2019년02월_여_99세  2019년02월_여_100세 이상
# 0            1138             828             622                4435
# 1              31              24              24                 161
# 2               2               2               2                  13
# 3               1               3               2                  14
# 4               0               0               2                   7
#
# [5 rows x 207 columns]

# %%
# Out:
# 0                서울특별시
# 1             서울특별시 종로구
# 2        서울특별시 종로구 청운효자동
# 3          서울특별시 종로구 사직동
# 4          서울특별시 종로구 삼청동
#               ...
# 3836    제주특별자치도 서귀포시 서홍동
# 3837    제주특별자치도 서귀포시 대륜동
# 3838    제주특별자치도 서귀포시 대천동
# 3839    제주특별자치도 서귀포시 중문동
# 3840    제주특별자치도 서귀포시 예래동
# Name: 행정구역, Length: 3841, dtype: object

# %%
data['대지역'] = data['행정구역'].str.split('(').str[0].str.split(' ').str[0]
data['중지역'] = data['행정구역'].str.split('(').str[0].str.split(' ').str[1]
data['소지역'] = data['행정구역'].str.split('(').str[0].str.split(' ').str[2]

# %%
data.head()
# Out:
#                           행정구역  2019년02월_남_총인구수  2019년02월_남_연령구간인구수  \
# 0          서울특별시  (1100000000)          4773605             4773605
# 1       서울특별시 종로구 (1111000000)            74662               74662
# 2  서울특별시 종로구 청운효자동(1111051500)             6088                6088
# 3    서울특별시 종로구 사직동(1111053000)             4313                4313
# 4    서울특별시 종로구 삼청동(1111054000)             1328                1328
#
#    2019년02월_남_0세  2019년02월_남_1세  2019년02월_남_2세  2019년02월_남_3세  2019년02월_남_4세  \
# 0          27977          30473          33735          36145          35828
# 1            318            334            395            434            435
# 2             27             39             36             55             53
# 3             19             30             27             34             33
# 4              6              6              2              9              7
#
#    2019년02월_남_5세  2019년02월_남_6세  ...  2019년02월_여_94세  2019년02월_여_95세  \
# 0          35485          38974  ...            2187            2069
# 1            426            501  ...              55              41
# 2             44             50  ...               3               3
# 3             37             41  ...               2               5
# 4              4              2  ...               2               0
#
#    2019년02월_여_96세  2019년02월_여_97세  2019년02월_여_98세  2019년02월_여_99세  \
# 0            1664            1138             828             622
# 1              49              31              24              24
# 2               4               2               2               2
# 3               6               1               3               2
# 4               1               0               0               2
#
#    2019년02월_여_100세 이상    대지역  중지역    소지역
# 0                4435  서울특별시
# 1                 161  서울특별시  종로구
# 2                  13  서울특별시  종로구  청운효자동
# 3                  14  서울특별시  종로구    사직동
# 4                   7  서울특별시  종로구    삼청동
#
# [5 rows x 210 columns]

# %%
data['남19세이하']=data.iloc[:,3:23].sum(axis=1)

# %%
data['여19세이하']=data.iloc[:,106:126].sum(axis=1)

# %%
data2 = data.iloc[:,207:214]

# %%
data3 = data2[data2['소지역'] != '']

# %%
data3
# Out:
#           대지역   중지역    소지역  남19세이하  여19세이하
# 2       서울특별시   종로구  청운효자동    1204    1079
# 3       서울특별시   종로구    사직동     699     747
# 4       서울특별시   종로구    삼청동     188     160
# 5       서울특별시   종로구    부암동     803     738
# 6       서울특별시   종로구    평창동    1585    1502
# ...       ...   ...    ...     ...     ...
# 3836  제주특별자치도  서귀포시    서홍동    1333    1322
# 3837  제주특별자치도  서귀포시    대륜동    1528    1345
# 3838  제주특별자치도  서귀포시    대천동    1471    1397
# 3839  제주특별자치도  서귀포시    중문동    1082    1064
# 3840  제주특별자치도  서귀포시    예래동     290     270
#
# [3595 rows x 5 columns]

# %%
data3[data3['중지역']=='의정부시']
# Out:
#       대지역   중지역    소지역  남19세이하  여19세이하
# 1364  경기도  의정부시  의정부1동    1075    1005
# 1365  경기도  의정부시  의정부2동    2367    2118
# 1366  경기도  의정부시  의정부3동     440     441
# 1367  경기도  의정부시   호원1동    2917    2750
# 1368  경기도  의정부시   호원2동    3393    3316
# 1369  경기도  의정부시    장암동    1874    1815
# 1370  경기도  의정부시   신곡1동    3806    3603
# 1371  경기도  의정부시   신곡2동    4632    4319
# 1372  경기도  의정부시   송산1동    2694    2593
# 1373  경기도  의정부시   송산2동   10163    9752
# 1374  경기도  의정부시    자금동    2711    2540
# 1375  경기도  의정부시    가능동    1892    1749
# 1376  경기도  의정부시    흥선동    1664    1477
# 1377  경기도  의정부시    녹양동    2287    2021

# %%
import matplotlib.pyplot as plt

# %%
men_x=data3[data3['중지역']=='의정부시'].iloc[:,2]

# %%
men_y=data3[data3['중지역']=='의정부시'].iloc[:,3]

# %%
plt.rc('font',family='Malgun Gothic')
plt.plot(men_x,men_y)
plt.show()

# %%
data3[data3['중지역']=='의정부시'].plot(x='소지역',rot=90)
plt.show()
