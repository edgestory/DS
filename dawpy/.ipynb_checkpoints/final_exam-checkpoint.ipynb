# %%
import pandas as pd
data = pd.read_csv('gender.csv',encoding='cp949')

# %%
data.head()
# Out:
#                           행정구역   남_총인구수  남_연령구간인구수   남_0세   남_1세   남_2세  \
# 0          서울특별시  (1100000000)  4773605    4773605  27977  30473  33735
# 1       서울특별시 종로구 (1111000000)    74662      74662    318    334    395
# 2  서울특별시 종로구 청운효자동(1111051500)     6088       6088     27     39     36
# 3    서울특별시 종로구 사직동(1111053000)     4313       4313     19     30     27
# 4    서울특별시 종로구 삼청동(1111054000)     1328       1328      6      6      2
#
#     남_3세   남_4세   남_5세   남_6세  ...  여_91세  여_92세  여_93세  여_94세  여_95세  여_96세  \
# 0  36145  35828  35485  38974  ...   5394   4054   3072   2187   2069   1664
# 1    434    435    426    501  ...    114     86     71     55     41     49
# 2     55     53     44     50  ...      4      4      9      3      3      4
# 3     34     33     37     41  ...     10      3      8      2      5      6
# 4      9      7      4      2  ...      5      2      0      2      0      1
#
#    여_97세  여_98세  여_99세  여_100세 이상
# 0   1138    828    622       4435
# 1     31     24     24        161
# 2      2      2      2         13
# 3      1      3      2         14
# 4      0      0      2          7
#
# [5 rows x 207 columns]

# %%
type(data.get('행정구역'))
# Out:
# pandas.core.series.Series

# %%
data['대지역'] = data['행정구역'].str.split('(').str[0].str.split(' ').str[0]
data['중지역'] = data['행정구역'].str.split('(').str[0].str.split(' ').str[1]
data['소지역'] = data['행정구역'].str.split('(').str[0].str.split(' ').str[2]

# %%
data.head()
# Out:
#                           행정구역   남_총인구수  남_연령구간인구수   남_0세   남_1세   남_2세  \
# 0          서울특별시  (1100000000)  4773605    4773605  27977  30473  33735
# 1       서울특별시 종로구 (1111000000)    74662      74662    318    334    395
# 2  서울특별시 종로구 청운효자동(1111051500)     6088       6088     27     39     36
# 3    서울특별시 종로구 사직동(1111053000)     4313       4313     19     30     27
# 4    서울특별시 종로구 삼청동(1111054000)     1328       1328      6      6      2
#
#     남_3세   남_4세   남_5세   남_6세  ...  여_94세  여_95세  여_96세  여_97세  여_98세  여_99세  \
# 0  36145  35828  35485  38974  ...   2187   2069   1664   1138    828    622
# 1    434    435    426    501  ...     55     41     49     31     24     24
# 2     55     53     44     50  ...      3      3      4      2      2      2
# 3     34     33     37     41  ...      2      5      6      1      3      2
# 4      9      7      4      2  ...      2      0      1      0      0      2
#
#    여_100세 이상    대지역  중지역    소지역
# 0       4435  서울특별시
# 1        161  서울특별시  종로구
# 2         13  서울특별시  종로구  청운효자동
# 3         14  서울특별시  종로구    사직동
# 4          7  서울특별시  종로구    삼청동
#
# [5 rows x 210 columns]

# %%
data['남19세이하']=data.iloc[:,3:23].sum(axis=1)

# %%
data['여19세이하']=data.iloc[:,106:126].sum(axis=1)

# %%
data.head()
# Out:
#                           행정구역   남_총인구수  남_연령구간인구수   남_0세   남_1세   남_2세  \
# 0          서울특별시  (1100000000)  4773605    4773605  27977  30473  33735
# 1       서울특별시 종로구 (1111000000)    74662      74662    318    334    395
# 2  서울특별시 종로구 청운효자동(1111051500)     6088       6088     27     39     36
# 3    서울특별시 종로구 사직동(1111053000)     4313       4313     19     30     27
# 4    서울특별시 종로구 삼청동(1111054000)     1328       1328      6      6      2
#
#     남_3세   남_4세   남_5세   남_6세  ...  여_96세  여_97세  여_98세  여_99세  여_100세 이상  \
# 0  36145  35828  35485  38974  ...   1664   1138    828    622       4435
# 1    434    435    426    501  ...     49     31     24     24        161
# 2     55     53     44     50  ...      4      2      2      2         13
# 3     34     33     37     41  ...      6      1      3      2         14
# 4      9      7      4      2  ...      1      0      0      2          7
#
#      대지역  중지역    소지역  남19세이하  여19세이하
# 0  서울특별시              788986  746867
# 1  서울특별시  종로구          10517   10312
# 2  서울특별시  종로구  청운효자동    1204    1079
# 3  서울특별시  종로구    사직동     699     747
# 4  서울특별시  종로구    삼청동     188     160
#
# [5 rows x 212 columns]

# %%
data2 = data.iloc[:,207:214]
data2.head()
# Out:
#      대지역  중지역    소지역  남19세이하  여19세이하
# 0  서울특별시              788986  746867
# 1  서울특별시  종로구          10517   10312
# 2  서울특별시  종로구  청운효자동    1204    1079
# 3  서울특별시  종로구    사직동     699     747
# 4  서울특별시  종로구    삼청동     188     160

# %%
data3 = data2[data2['소지역'] != '']

# %%
data3
# Out:
#           대지역   중지역          소지역  남19세이하  여19세이하
# 2       서울특별시   종로구        청운효자동    1204    1079
# 3       서울특별시   종로구          사직동     699     747
# 4       서울특별시   종로구          삼청동     188     160
# 5       서울특별시   종로구          부암동     803     738
# 6       서울특별시   종로구          평창동    1585    1502
# 7       서울특별시   종로구          무악동     817     939
# 8       서울특별시   종로구          교남동     894     924
# 9       서울특별시   종로구          가회동     306     291
# 10      서울특별시   종로구  종로1.2.3.4가동     252     221
# 11      서울특별시   종로구      종로5.6가동     214     207
# 12      서울특별시   종로구          이화동     408     413
# 13      서울특별시   종로구          혜화동    1098    1148
# 14      서울특별시   종로구        창신제1동     239     237
# 15      서울특별시   종로구        창신제2동     471     441
# 16      서울특별시   종로구        창신제3동     541     498
# 17      서울특별시   종로구        숭인제1동     393     395
# 18      서울특별시   종로구        숭인제2동     405     372
# 20      서울특별시    중구          소공동     130     170
# 21      서울특별시    중구          회현동     210     218
# 22      서울특별시    중구           명동     105     119
# 23      서울특별시    중구           필동     228     196
# 24      서울특별시    중구          장충동     274     290
# 25      서울특별시    중구          광희동     192     182
# 26      서울특별시    중구         을지로동      48      39
# 27      서울특별시    중구          신당동     314     329
# 28      서울특별시    중구          다산동     876     782
# 29      서울특별시    중구          약수동    1199    1190
# 30      서울특별시    중구          청구동    1000     942
# 31      서울특별시    중구        신당제5동     591     628
# 32      서울특별시    중구          동화동     880     871
# ...       ...   ...          ...     ...     ...
# 3810  제주특별자치도   제주시         용담1동     623     559
# 3811  제주특별자치도   제주시         용담2동    1441    1332
# 3812  제주특별자치도   제주시          건입동     821     764
# 3813  제주특별자치도   제주시          화북동    3134    2831
# 3814  제주특별자치도   제주시          삼양동    3575    3271
# 3815  제주특별자치도   제주시          봉개동     542     460
# 3816  제주특별자치도   제주시          아라동    4208    4321
# 3817  제주특별자치도   제주시          오라동    2033    1831
# 3818  제주특별자치도   제주시           연동    4119    3797
# 3819  제주특별자치도   제주시          노형동    7056    6415
# 3820  제주특별자치도   제주시          외도동    3066    2868
# 3821  제주특별자치도   제주시          이호동     460     401
# 3822  제주특별자치도   제주시          도두동     291     308
# 3824  제주특별자치도  서귀포시          대정읍    2225    2052
# 3825  제주특별자치도  서귀포시          남원읍    1547    1383
# 3826  제주특별자치도  서귀포시          성산읍    1058     998
# 3827  제주특별자치도  서귀포시          안덕면     942     882
# 3828  제주특별자치도  서귀포시          표선면     964     861
# 3829  제주특별자치도  서귀포시          송산동     364     305
# 3830  제주특별자치도  서귀포시          정방동     143     132
# 3831  제주특별자치도  서귀포시          중앙동     265     245
# 3832  제주특별자치도  서귀포시          천지동     226     232
# 3833  제주특별자치도  서귀포시          효돈동     417     401
# 3834  제주특별자치도  서귀포시          영천동     414     403
# 3835  제주특별자치도  서귀포시          동홍동    2818    2729
# 3836  제주특별자치도  서귀포시          서홍동    1333    1322
# 3837  제주특별자치도  서귀포시          대륜동    1528    1345
# 3838  제주특별자치도  서귀포시          대천동    1471    1397
# 3839  제주특별자치도  서귀포시          중문동    1082    1064
# 3840  제주특별자치도  서귀포시          예래동     290     270
#
# [3595 rows x 5 columns]

# %%
data3[data3['소지역']=='송산3동']
# Out:
# Empty DataFrame
# Columns: [대지역, 중지역, 소지역, 남19세이하, 여19세이하]
# Index: []

# %%
import matplotlib.pyplot as plt

# %%
men_x=data3[data3['중지역']=='의정부시'].iloc[:,2]

# %%
men_y=data3[data3['중지역']=='의정부시'].iloc[:,3]

# %%
plt.rc('font',family='Malgun Gothic')
plt.barh(men_x,men_y)
plt.show()

# %%
data3[data3['중지역']=='의정부시'].plot(x='소지역',rot=90).bar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-667e4de8e67e> in <module>
# ----> 1 data3[data3['중지역']=='의정부시'].plot(x='소지역',rot=90).bar()
#       2 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: bar() missing 2 required positional arguments: 'x' and 'height'
