# %%
import cx_Oracle
import pandas as pd

# %%
dsn = cx_Oracle.makedsn("prod-oracle-ods.cjamvqrfufii.ap-northeast-1.rds.amazonaws.com",1521,"orcl")

# %%
db = cx_Oracle.connect("david","비밀번호",dsn)

# %%
cursor = db.cursor()
cursor.execute("select idx from hotel")
result=cursor.fetchall()

# %%
df = pd.DataFrame(result)

# %%
df.head()
# Out:
#        0
# 0  29334
# 1    832
# 2    868
# 3    876
# 4    940

# %%
result
# Out:
# [(29334,),
#  (832,),
#  (868,),
#  (876,),
#  (940,),
#  (27682,),
#  (808,),
#  (810,),
#  (814,),
#  (827,),
#  (828,),
#  (835,),
#  (885,),
#  (887,),
#  (922,),
#  (925,),
#  (1056,),
#  (1555,),
#  (1697,),
#  (1726,),
#  (1733,),
#  (1745,),
#  (1763,),
#  (1868,),
#  (1869,),
#  (1913,),
#  (2002,),
#  (2805,),
#  (2918,),
#  (2922,),
#  (3272,),
#  (3424,),
#  (3747,),
#  (4205,),
#  (4340,),
#  (4355,),
#  (869,),
#  (875,),
#  (889,),
#  (7836,),
#  (11158,),
#  (11877,),
#  (11880,),
#  (12002,),
#  (12009,),
#  (12023,),
#  (12053,),
#  (12069,),
#  (12163,),
#  (12175,),
#  (12232,),
#  (12259,),
#  (12286,),
#  (12290,),
#  (12308,),
#  (12317,),
#  (12318,),
#  (12323,),
#  (12340,),
#  (12346,),
#  (12357,),
#  (12361,),
#  (16342,),
#  (17687,),
#  (20679,),
#  (20740,),
#  (20779,),
#  (23933,),
#  (26144,),
#  (27864,),
#  (26253,),
#  (26254,),
#  (26267,),
#  (26282,),
#  (26291,),
#  (27609,),
#  (27610,),
#  (27666,),
#  (27680,),
#  (27681,),
#  (27685,),
# ...
