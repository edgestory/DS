# %% [markdown]
# # 목차
# 1. 그래프 그리기 의미
# 2. Tidy 데이터

# %% [markdown]
# ## 1. 그래프 그리기의 의미
#
# 참조 url : https://www.autodeskresearch.com/publications/samestats
#
# * 데이터의 형태 살피기
# * 분포를 유추
# * 아웃라이어 감지
#
#
# * 데이터의 대표값(요약값)만으로는 데이터의 형태를 오판할수 있음
#     * 아래와 같이 평균, 표준편차가 거의 동일한 값을 갖지만
#     * scatter plot으로 그래프를 그려보면 굉장히 다른 형태의 테이터임을 알수 있음

# %%
import pandas as pd

data = pd.read_csv('DatasaurusDozen.tsv',sep='\t')

# %%
data
# Out:
#          dataset          x          y
# 0           dino  55.384600  97.179500
# 1           dino  51.538500  96.025600
# 2           dino  46.153800  94.487200
# 3           dino  42.820500  91.410300
# 4           dino  40.769200  88.333300
# ...          ...        ...        ...
# 1841  wide_lines  33.674442  26.090490
# 1842  wide_lines  75.627255  37.128752
# 1843  wide_lines  40.610125  89.136240
# 1844  wide_lines  39.114366  96.481751
# 1845  wide_lines  34.583829  89.588902
#
# [1846 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from plotnine import *

# %%
data['dataset'].unique()
# Out:
# array(['dino', 'away', 'h_lines', 'v_lines', 'x_shape', 'star',
#        'high_lines', 'dots', 'circle', 'bullseye', 'slant_up',
#        'slant_down', 'wide_lines'], dtype=object)

# %%
dino = data[data['dataset']=='dino']
away = data[data['dataset']=='away']
h_lines = data[data['dataset']=='h_lines']
v_lines = data[data['dataset']=='v_lines']
x_shape = data[data['dataset']=='x_shape']
star = data[data['dataset']=='star']
high_lines = data[data['dataset']=='high_lines']
dots = data[data['dataset']=='dots']
circle = data[data['dataset']=='circle']
bullseye = data[data['dataset']=='bullseye']
slant_up = data[data['dataset']=='slant_up']
slant_down = data[data['dataset']=='slant_down']
wide_lines = data[data['dataset']=='wide_lines']

# %%
fig=plt.Figure()

# %%
ggplot(dino, aes(x='x',y='y')) + geom_point()
# Out:
# 54.26327323943664

# %%
x_mean = dino['x'].mean()
y_mean = dino['y'].mean()
x_sd = dino['x'].std()
y_sd = dino['y'].std()
cor= dino.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.26327323943664 47.832252816901374 16.765142039116785 26.935403486939123 -0.06447185270095167

# %%
ggplot(away, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883515491628)>

# %%
x_mean = away['x'].mean()
y_mean = away['y'].mean()
x_sd = away['x'].std()
y_sd = away['y'].std()
cor= away.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.26609978420493 47.83472062488411 16.769824954157368 26.939743418883353 -0.06412835215474479

# %%
ggplot(h_lines, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883515445612)>

# %%
plt.scatter(dino['x'],dino['y'])

# %%
x_mean = away['x'].mean()
y_mean = away['y'].mean()
x_sd = away['x'].std()
y_sd = away['y'].std()
cor= away.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.26609978420493 47.83472062488411 16.769824954157368 26.939743418883353 -0.06412835215474479

# %%
ggplot(v_lines, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883514291372)>

# %%
x_mean = v_lines['x'].mean()
y_mean = v_lines['y'].mean()
x_sd = v_lines['x'].std()
y_sd = v_lines['y'].std()
cor= v_lines.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.26992723102747 47.83698798816882 16.76995861135582 26.93768380697394 -0.0694455695981722

# %%
ggplot(x_shape, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883514288580)>

# %%
x_mean = x_shape['x'].mean()
y_mean = x_shape['y'].mean()
x_sd = x_shape['x'].std()
y_sd = x_shape['y'].std()
cor= x_shape.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.26015033403806 47.839717279160446 16.76995769581929 26.930001686980987 -0.06558333731006556

# %%
ggplot(star, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883514289520)>

# %%
x_mean = x_shape['x'].mean()
y_mean = x_shape['y'].mean()
x_sd = x_shape['x'].std()
y_sd = x_shape['y'].std()
cor= x_shape.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.26015033403806 47.839717279160446 16.76995769581929 26.930001686980987 -0.06558333731006556

# %%
ggplot(high_lines, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883514171464)>

# %%
x_mean = high_lines['x'].mean()
y_mean = high_lines['y'].mean()
x_sd = high_lines['x'].std()
y_sd = high_lines['y'].std()
cor= high_lines.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.26880527974155 47.835450203936624 16.766704016169232 26.939997961212953 -0.06850422050586685

# %%
ggplot(dots, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883514189224)>

# %%
x_mean = dots['x'].mean()
y_mean = dots['y'].mean()
x_sd = dots['x'].std()
y_sd = dots['y'].std()
cor= dots.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.260303451217624 47.83982920875562 16.7677354884326 26.930191518085515 -0.060341441993538567

# %%
ggplot(circle, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883515576360)>

# %%
x_mean = circle['x'].mean()
y_mean = circle['y'].mean()
x_sd = circle['x'].std()
y_sd = circle['y'].std()
cor= circle.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.26731970617395 47.83771726721833 16.760012659672196 26.93003608783035 -0.06834335645012023

# %%
ggplot(bullseye, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883514193376)>

# %%
x_mean = bullseye['x'].mean()
y_mean = bullseye['y'].mean()
x_sd = bullseye['x'].std()
y_sd = bullseye['y'].std()
cor= bullseye.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.26873002237886 47.8308231552178 16.76923949342675 26.93572668988594 -0.06858639425794842

# %%
ggplot(slant_up, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883515434712)>

# %%
x_mean = slant_up['x'].mean()
y_mean = slant_up['y'].mean()
x_sd = slant_up['x'].std()
y_sd = slant_up['y'].std()
cor= slant_up.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.26588178560211 47.83149565202442 16.7688526706285 26.938608070892247 -0.06860920644502208

# %%
ggplot(slant_down, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883514096560)>

# %%
x_mean = slant_down['x'].mean()
y_mean = slant_down['y'].mean()
x_sd = slant_down['x'].std()
y_sd = slant_down['y'].std()
cor= slant_down.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.2678488233662 47.83589633058821 16.766758947404618 26.936104931637747 -0.06897973536063169

# %%
ggplot(wide_lines, aes(x='x',y='y')) + geom_point()
# Out:
# <ggplot: (-9223371883515528688)>

# %%
x_mean = wide_lines['x'].mean()
y_mean = wide_lines['y'].mean()
x_sd = wide_lines['x'].std()
y_sd = wide_lines['y'].std()
cor= wide_lines.corr(method='pearson').iloc[0,1]
print(x_mean,y_mean,x_sd,y_sd,cor)
# Out:
# 54.266916301257034 47.83160198800619 16.76999961796734 26.937901927715227 -0.066575230199981

# %% [markdown]
# ## 2. Tidy 데이터
#
# *깔끔한 데이터

# %% [markdown]
# Tidy data(깔끔한 데이터)는 Hadley Wickham이 2014년 The Journal of Statistical Software에서 발표한, 데이터 관리를 위한 새로운 개념이다. Tidy data를 우리말로 쉽게 풀이하면 '분석하기 좋은 데이터'로 표현할 수 있다. Hadley는 위 논문을 통해 데이터를 바라보는 새로운 시점을 제안하였고 이후 최근까지 짧은 시간 동안 200회에 가까운 인용 수를 기록하며 많은 관련 분야 연구원들에게 영향을 미치고 있다.
#
# 데이터셋을 타이디하게 만드는, 서로 연관된 세 가지 규칙이 있다.
#
# 변수마다 해당되는 열이 있어야 한다.
# 관측값마다 해당되는 행이 있어야 한다.
# 값마다 해당하는 하나의 셀이 있어야 한다.
# Figure 4.1 은 이러한 규칙을 시각적으로 보여준다.
#
# ![image.png](attachment:image.png)
# Figure 4.1: 데이터셋을 타이디하게 만드는 세 가지 규칙: 변수는 열에 있고, 관측값은 행에 있고, 값은 셀에 있다.

# %% [markdown]
# ### gather
#
# *변수가 아니라 값을 나타내는 열 집합
# *year라는 변수를 만들고, 값을 넣는다
# *값을 표현하는 cases라는 변수를 추가한다
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Spread
#
# * 변수 이름을 포함하는 열이 있음
# * 여러 변수를 각각 열로 나누어 준다
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### separate
#
# *구분자로 되어있는 칼럼을 쪼갠다
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1단원 복습
#
# * 그래프
#     * barplot
#     * lineplot
#     * boxplot
#     * violinplot
#     * hist
#     * distplot
#     * kdeplot(밀도, 누적 그래프)
#     * pairplot
#     * heatmap
#     * pointplot
#     * swarmplot
#
# * 계산
#     * groupby 연산
#     * pivot_table
#     * transpose
#     *
